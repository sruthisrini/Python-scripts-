# %% [markdown]
# # Reading the tsv file and filtering out the required columns

# %%
import pandas as pd
import numpy as np

df=pd.read_csv("metadata_processed_files_hg38.tsv",sep='\t')
df.head()
# Out:
#   File accession File format File type File format type  \
# 0    ENCFF404WOP         bam       bam              NaN
# 1    ENCFF080HMO         bam       bam              NaN
# 2    ENCFF224ZJZ      bigWig    bigWig              NaN
# 3    ENCFF394GOQ      bigWig    bigWig              NaN
# 4    ENCFF292ZPN      bigWig    bigWig              NaN
#
#                            Output type File assembly Experiment accession  \
# 0                           alignments        GRCh38          ENCSR977OXG
# 1                           alignments        GRCh38          ENCSR977OXG
# 2  minus strand signal of unique reads        GRCh38          ENCSR977OXG
# 3  minus strand signal of unique reads        GRCh38          ENCSR977OXG
# 4   plus strand signal of unique reads        GRCh38          ENCSR977OXG
#
#    Assay                    Donor(s) Biosample term id  ... Platform  \
# 0  eCLIP  /human-donors/ENCDO000AAC/       EFO:0001187  ...      NaN
# 1  eCLIP  /human-donors/ENCDO000AAC/       EFO:0001187  ...      NaN
# 2  eCLIP  /human-donors/ENCDO000AAC/       EFO:0001187  ...      NaN
# 3  eCLIP  /human-donors/ENCDO000AAC/       EFO:0001187  ...      NaN
# 4  eCLIP  /human-donors/ENCDO000AAC/       EFO:0001187  ...      NaN
#
#   Controlled by File Status  \
# 0           NaN    released
# 1           NaN    released
# 2           NaN    released
# 3           NaN    released
# 4           NaN    released
#
#                                               s3_uri  \
# 0  s3://encode-public/2018/04/29/1458851f-4eea-49...
# 1  s3://encode-public/2018/04/29/4f972b21-cdae-4f...
# 2  s3://encode-public/2018/04/29/43cd0f31-3fad-4a...
# 3  s3://encode-public/2018/04/29/8150c9a3-df05-49...
# 4  s3://encode-public/2018/04/29/f0792594-45b9-43...
#
#                                            Azure URL  File analysis title  \
# 0  https://datasetencode.blob.core.windows.net/da...    Lab custom GRCh38
# 1  https://datasetencode.blob.core.windows.net/da...    Lab custom GRCh38
# 2  https://datasetencode.blob.core.windows.net/da...    Lab custom GRCh38
# 3  https://datasetencode.blob.core.windows.net/da...    Lab custom GRCh38
# 4  https://datasetencode.blob.core.windows.net/da...    Lab custom GRCh38
#
#    File analysis status  Audit WARNING  Audit NOT_COMPLIANT  Audit ERROR
# 0              released            NaN                  NaN          NaN
# 1              released            NaN                  NaN          NaN
# 2              released            NaN                  NaN          NaN
# 3              released            NaN                  NaN          NaN
# 4              released            NaN                  NaN          NaN
#
# [5 rows x 59 columns]

# %%
df=df.loc[:,["File accession","File format","File assembly","Biosample term name","Experiment target","Biological replicate(s)","md5sum","File download URL"]]

# %%
df=df[(df["File format"]=="bed narrowPeak")&(df["Biological replicate(s)"]=="1, 2")&(df["File assembly"]=="GRCh38")&(df["Biosample term name"].isin(["HepG2","K562"]))]

# %%
df.to_csv("metadata_processed_files_hg38_version_1.tsv")

# %%
df.shape
# Out:
# (238, 8)
